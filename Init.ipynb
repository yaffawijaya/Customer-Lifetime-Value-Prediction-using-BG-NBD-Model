# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here.
# if test -f requirements.txt
#   then
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install."
# fi
# Out:
# Collecting lifetimes==0.11.3
#   Downloading Lifetimes-0.11.3-py3-none-any.whl (584 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 584.2/584.2 kB 34.8 MB/s eta 0:00:00
# Collecting yellowbrick==1.5
#   Downloading yellowbrick-1.5-py3-none-any.whl (282 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 282.6/282.6 kB 37.7 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from lifetimes==0.11.3->-r ./requirements.txt (line 1)) (1.9.3)
# Requirement already satisfied: dill>=0.2.6 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from lifetimes==0.11.3->-r ./requirements.txt (line 1)) (0.3.5.1)
# Requirement already satisfied: numpy>=1.10.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from lifetimes==0.11.3->-r ./requirements.txt (line 1)) (1.23.4)
# Collecting autograd>=1.2.0
#   Downloading autograd-1.6.2-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 9.8 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=0.24.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from lifetimes==0.11.3->-r ./requirements.txt (line 1)) (2.1.4)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.2 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from yellowbrick==1.5->-r ./requirements.txt (line 2)) (3.6.0)
# Requirement already satisfied: scikit-learn>=1.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from yellowbrick==1.5->-r ./requirements.txt (line 2)) (1.1.2)
# Requirement already satisfied: cycler>=0.10.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from yellowbrick==1.5->-r ./requirements.txt (line 2)) (0.11.0)
# Requirement already satisfied: future>=0.15.2 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from autograd>=1.2.0->lifetimes==0.11.3->-r ./requirements.txt (line 1)) (0.18.2)
# Requirement already satisfied: pillow>=6.2.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick==1.5->-r ./requirements.txt (line 2)) (9.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick==1.5->-r ./requirements.txt (line 2)) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick==1.5->-r ./requirements.txt (line 2)) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick==1.5->-r ./requirements.txt (line 2)) (1.0.5)
# Requirement already satisfied: fonttools>=4.22.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick==1.5->-r ./requirements.txt (line 2)) (4.37.4)
# Requirement already satisfied: packaging>=20.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick==1.5->-r ./requirements.txt (line 2)) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick==1.5->-r ./requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas>=0.24.0->lifetimes==0.11.3->-r ./requirements.txt (line 1)) (2022.5)
# Requirement already satisfied: pytz>=2020.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas>=0.24.0->lifetimes==0.11.3->-r ./requirements.txt (line 1)) (2022.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from scikit-learn>=1.0.0->yellowbrick==1.5->-r ./requirements.txt (line 2)) (3.1.0)
# Requirement already satisfied: joblib>=1.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from scikit-learn>=1.0.0->yellowbrick==1.5->-r ./requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: six>=1.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib!=3.0.0,>=2.0.2->yellowbrick==1.5->-r ./requirements.txt (line 2)) (1.16.0)
# Installing collected packages: autograd, yellowbrick, lifetimes
# Successfully installed autograd-1.6.2 lifetimes-0.11.3 yellowbrick-1.5
#
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=b6862784-1edd-41cc-8ccf-a184a726a01c' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
